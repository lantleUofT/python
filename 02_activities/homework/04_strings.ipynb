# %% [markdown]
# # Strings
# ## Practice Problems

# %% [markdown]
# ### 1. Write a multi-line string about anything you want and print it

# %%
# Your code goes here

string = "yayyyy big string"
string
# Out:
# 'yayyyy big string'

# %% [markdown]
# ### 2. Append a "world" to the following word.

# %%
# Your code goes here
string + " world"
# Out:
# 'yayyyy big string world'
